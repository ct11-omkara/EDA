# %%
import pandas as pd
import numpy as np
import json
import sys
import csv

# %% [markdown]
# # list of commands statements in this page

# %% [raw]
# pandas.core.series.Seriesdb = pd.read_csv('All_data_files\\exe1.csv')
# db = pd.read_table('All_data_files\\exe1.csv', ',')
# db.head()
# db.tail()
#
# db1 = pd.read_csv('All_data_files\\test.tsv')
# db1 = pd.read_table('All_data_files\\test.tsv')
# db1 = pd.read_csv('All_data_files\\test.tsv', sep='\t')
#
# db = pd.read_csv('All_data_files\\exe1.csv', header = None)
# db = pd.read_csv('All_data_files\\exe1.csv', names=['at','bt','ct','dt','et','ft','gt','ht'])
#
# db = pd.read_csv('All_data_files\\csv_index.csv')
# db = pd.read_csv('All_data_files\\csv_index.csv', index_col=['key1'])
# db = pd.read_csv('All_data_files\\csv_index.csv', index_col=['key1', 'key2'])
#
# db = pd.read_csv('All_data_files\\exe2.csv')
# db = pd.read_csv('All_data_files\\exe2.csv', skiprows = [0,2,3])
#
# pd.isnull(db)
# db.isnull()
#
# db = pd.read_excel("All_data_files\\test1.xlsx")
# db = pd.read_excel('All_data_files\\test1.xlsx', sheet_name='Sheet2')
#
# db = pd.read_html('All_data_files\\ct.html')
# db[0]
# db[1]
# db[2]
# len(db)
# - 3
#
# type(df['Size'])
# - pandas.core.series.Series
# type(df[["Size"]])
# - pandas.core.frame.DataFrame
#
# df["Size"]
# df[['Size', 'MD5']]
#
# df.columns
# - Index([u'Filename', u'Size', u'Last Modified', u'MD5'], dtype='object')
# df.dtypes
# - India    int64
#   USA      int64
#   Japan    int64
#   Fance    int64
#   dtype: object
#
# url = "https://raw.githubusercontent.com/akhil12028/Bank-Marketing-data-set-analysis/master/bank-additional-full.csv"
# bankDF = pd.read_csv(url, sep=';', header=None, skiprows=[0,2,4])
#
# url = "All_data_files\\bank-additional-full.csv"
# bankDF = pd.read_csv(url, sep=';', names=['ct', 'kt', 'rt', 'rt', 'yt'])
# bankDF = pd.read_csv(url, sep=';', nrows=10)

# %% [markdown]
# # CSV, TSV, Excel, html tables, JSON file reading operations
# with the help of read_csv(), read_tsv(), read_excel(), read_html(), json.loads()

# %% [markdown]
# # Readind CSV file without using Pandas's Functions, just using csv library
# with the help of csv.reader()

# %% [markdown]
# # CSV file writing operations
# with the help of to_csv(), sys.stdout()

# %% [markdown]
# # Reading and writing data to the file in to BINARY format
# Pickle file, (.h5) format file

# %% [markdown]
# # --------------------------------------------------------------------------------------------------------

# %% [markdown]
# # CSV, TSC, Excel, HTML, JSON File operations

# %%
db = pd.read_csv('All_data_files\\exe1.csv')
db.head()
# Out:
#    a   b     c    d message
# 0  1   2   3.0  4.0   hello
# 1  5   6   NaN  8.0   world
# 2  9  10  11.0  NaN     foo

# %% [markdown]
# .csv file is read by read_table()

# %%
db = pd.read_table('All_data_files\\exe1.csv', ',')
db.head()
# Out:
# C:\Users\OMKARA\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead.
#   """Entry point for launching an IPython kernel.
#    a   b     c    d message
# 0  1   2   3.0  4.0   hello
# 1  5   6   NaN  8.0   world
# 2  9  10  11.0  NaN     foo

# %%
db.tail(1)
# Out:
#    a   b     c   d message
# 2  9  10  11.0 NaN     foo

# %% [markdown]
# .tsv (Tab Saperated Values) file

# %%
db1 = pd.read_csv('All_data_files\\test.tsv')
db1.head()
# Out:
#   a\tb\tc\td\tmessage
# 0   1\t2\t3\t4\thello
# 1   5\t6\t7\t8\tworld
# 2  9\t10\t11\t12\tfoo

# %% [markdown]
# .tsv file is read by read_table()

# %%
db1 = pd.read_table('All_data_files\\test.tsv')
db1.head()
# Out:
# C:\Users\OMKARA\Anaconda2\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: read_table is deprecated, use read_csv instead, passing sep='\t'.
#   """Entry point for launching an IPython kernel.
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %% [markdown]
# .tsv file is read by read_csv()

# %%
db1 = pd.read_csv('All_data_files\\test.tsv', sep='\t')
db1.head()
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %% [markdown]
# # HEADER

# %%
db = pd.read_csv('All_data_files\\exe1.csv')
db.head()
# Out:
#    a   b     c    d message
# 0  1   2   3.0  4.0   hello
# 1  5   6   NaN  8.0   world
# 2  9  10  11.0  NaN     foo

# %% [markdown]
# First row is not taken as header

# %%
db = pd.read_csv('All_data_files\\exe1.csv', header = None)
db.head()
# Out:
#    0   1    2    3        4
# 0  a   b    c    d  message
# 1  1   2    3    4    hello
# 2  5   6  NaN    8    world
# 3  9  10   11  NaN      foo

# %% [markdown]
# Give own header

# %%
db = pd.read_csv('All_data_files\\exe1.csv', names=['at','bt','ct','dt','et','ft','gt','ht'])
db.head()
# Out:
#   at  bt   ct   dt       et  ft  gt  ht
# 0  a   b    c    d  message NaN NaN NaN
# 1  1   2    3    4    hello NaN NaN NaN
# 2  5   6  NaN    8    world NaN NaN NaN
# 3  9  10   11  NaN      foo NaN NaN NaN

# %% [markdown]
# # INDEXING

# %%
db = pd.read_csv('All_data_files\\csv_index.csv')
db
# Out:
#   key1 key2  value1  value2
# 0  one    a       1       2
# 1  one    b       3       4
# 2  one    c       5       6
# 3  one    d       7       8
# 4  two    a       9      10
# 5  two    b      11      12
# 6  two    c      13      14
# 7  two    d      15      16

# %% [markdown]
# Make first column as index

# %%
db = pd.read_csv('All_data_files\\csv_index.csv', index_col=['key1'])
db
# Out:
#      key2  value1  value2
# key1
# one     a       1       2
# one     b       3       4
# one     c       5       6
# one     d       7       8
# two     a       9      10
# two     b      11      12
# two     c      13      14
# two     d      15      16

# %% [markdown]
# Make first two columns as index

# %%
db = pd.read_csv('All_data_files\\csv_index.csv', index_col=['key1', 'key2'])
db
# Out:
#            value1  value2
# key1 key2
# one  a          1       2
#      b          3       4
#      c          5       6
#      d          7       8
# two  a          9      10
#      b         11      12
#      c         13      14
#      d         15      16

# %% [markdown]
# # Skiping Rows operations

# %%
db = pd.read_csv('All_data_files\\exe2.csv')
db
# Out:
#                                                                     # hey!
# a                                                b        c   d    message
# # just want to make thing more difficult for you NaN      NaN NaN      NaN
# # who read csv files with comuters                always? NaN NaN      NaN
# 1                                                2        3   4      hello
# 5                                                6        7   8      world
# 9                                                10       11  12       foo

# %%
db = pd.read_csv('All_data_files\\exe2.csv', skiprows = [0,2,3])
db
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %% [markdown]
#   # See None/NaN data in the csv file with True/False format

# %%
db = pd.read_csv('All_data_files\\exe3.csv')
db
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %% [markdown]
# pd.isnull(db) & db.isnull() both are equal.

# %%
db = pd.read_csv('All_data_files\\exe3.csv')
pd.isnull(db)
# Out:
#    something      a      b      c      d  message
# 0      False  False  False  False  False     True
# 1      False  False  False   True  False    False
# 2      False  False  False  False  False    False

# %%
db.isnull()
# Out:
#    something      a      b      c      d  message
# 0      False  False  False  False  False     True
# 1      False  False  False   True  False    False
# 2      False  False  False  False  False    False

# %% [markdown]
# # Reading Excel data
# Read Sheet1(Default - First one) data from test1.xlsx excel file.

# %%
db = pd.read_excel("All_data_files\\test1.xlsx")
db
# Out:
#   dgdgdg  nhjh cxcx ggjg   kjk
# 0    NaN   NaN  NaN  NaN   NaN
# 1    gdg   fff  NaN  NaN   fhf
# 2    NaN   NaN   hf  hfh   NaN
# 3     mk  aqwq  NaN  NaN  gfgf
# 4    sfs   NaN    a  dsd   NaN

# %% [markdown]
# Read Sheet2 data from test1.xlsx excel file.

# %%
db = pd.read_excel('All_data_files\\test1.xlsx', sheet_name='Sheet2')
db
# Out:
#    rrtrt   uyu ioyiy  sas
# 0    asa   NaN   dfd  NaN
# 1    dad   dfd   NaN  ghg
# 2    NaN  sdsd   ghg  NaN
# 3  errer   NaN  rgrt  NaN

# %% [markdown]
# # Reading .html file data
# read_html() fetches all the Tables data (ONLY TABLES DATA) from ct.html Web Page and stores it as elements in to db list object... All other data (EXCEPT TABLES DATA) from ct.html Web Page, will not be stored as elements in db object.

# %%
db = pd.read_html('All_data_files\\ct.html')
type(db)
# Out:
# list

# %% [markdown]
# It will show all the Tables elements stored in db object.

# %%
db
# Out:
# [  Filename   Size        Last Modified     MD5
#  0    json1  103 B  2021-01-08 06:19:41  7b4829
#  1    json2  117 B  2021-01-08 06:19:41  2bbdef
#  2    json3  120 B  2021-01-08 06:19:41  f1b9f4,    India  USA  Japan  Fance
#  0     13   45     33     23
#  1     67   56     44     87
#  2     76   35     97     54,         0      1            2     3
#  0  Russia  China  North Korea  Cuba
#  1      13     45           33    23
#  2      67     56           44    87
#  3      76     35           97    54]

# %% [markdown]
# It will show the first Table element stored in db object.

# %%
db[0]
# Out:
#   Filename   Size        Last Modified     MD5
# 0    json1  103 B  2021-01-08 06:19:41  7b4829
# 1    json2  117 B  2021-01-08 06:19:41  2bbdef
# 2    json3  120 B  2021-01-08 06:19:41  f1b9f4

# %% [markdown]
# It will show the second Table element stored in db object.

# %%
db[1]
# Out:
#    India  USA  Japan  Fance
# 0     13   45     33     23
# 1     67   56     44     87
# 2     76   35     97     54

# %% [markdown]
# It will show the third Table element stored in db object.

# %%
db[2]
# Out:
#         0      1            2     3
# 0  Russia  China  North Korea  Cuba
# 1      13     45           33    23
# 2      67     56           44    87
# 3      76     35           97    54

# %% [markdown]
# It will show an error message, because there no more Table element stored in db object.

# %%
db[3]
# Out:
# IndexErrorTraceback (most recent call last)
# <ipython-input-53-5404aaacc7f1> in <module>()
# ----> 1 db[3]
#
# IndexError: list index out of range

# %%
type(db)
# Out:
# list

# %%
df=db[0]
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#   Filename   Size        Last Modified     MD5
# 0    json1  103 B  2021-01-08 06:19:41  7b4829
# 1    json2  117 B  2021-01-08 06:19:41  2bbdef
# 2    json3  120 B  2021-01-08 06:19:41  f1b9f4

# %%
df["Size"]
# Out:
# 0    103 B
# 1    117 B
# 2    120 B
# Name: Size, dtype: object

# %%
type(df['Size'])
# Out:
# pandas.core.series.Series

# %%
df[["Size"]]
# Out:
#     Size
# 0  103 B
# 1  117 B
# 2  120 B

# %%
type(df[["Size"]] )
# Out:
# pandas.core.frame.DataFrame

# %%
type(df[['Size', 'MD5']])
# Out:
# pandas.core.frame.DataFrame

# %%
df[['Size', 'MD5']]
# Out:
#     Size     MD5
# 0  103 B  7b4829
# 1  117 B  2bbdef
# 2  120 B  f1b9f4

# %%
df.columns
# Out:
# Index([u'Filename', u'Size', u'Last Modified', u'MD5'], dtype='object')

# %%
df=db[1]
df.dtypes
# Out:
# India    int64
# USA      int64
# Japan    int64
# Fance    int64
# dtype: object

# %%
data = pd.read_html('All_data_files\\FDIC _ Failed Bank List.html')
len(data)
# Out:
# 1

# %%
data
# Out:
# [                                            Bank Name               City  \
#  0                                   Almena State Bank             Almena
#  1                          First City Bank of Florida  Fort Walton Beach
#  2                                The First State Bank      Barboursville
#  3                                  Ericson State Bank            Ericson
#  4                    City National Bank of New Jersey             Newark
#  5                                       Resolute Bank             Maumee
#  6                               Louisa Community Bank             Louisa
#  7                                The Enloe State Bank             Cooper
#  8                 Washington Federal Bank for Savings            Chicago
#  9     The Farmers and Merchants State Bank of Argonia            Argonia
#  10                                Fayette County Bank         Saint Elmo
#  11  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...          Milwaukee
#
# ...

# %% [markdown]
# # Practice Datframe

# %%
url = "https://raw.githubusercontent.com/akhil12028/Bank-Marketing-data-set-analysis/master/bank-additional-full.csv"
#url = "All_data_files\\bank-additional-full.csv" #stored file in local machine
bankDF = pd.read_csv(url, sep=';', header=None, skiprows=[0,2,4])
bankDF.head(10)
# Out:
#    0            1        2                    3        4    5    6   \
# 0  56    housemaid  married             basic.4y       no   no   no
# 1  37     services  married          high.school       no  yes   no
# 2  56     services  married          high.school       no   no  yes
# 3  45     services  married             basic.9y  unknown   no   no
# 4  59       admin.  married  professional.course       no   no   no
# 5  41  blue-collar  married              unknown  unknown   no   no
# 6  24   technician   single  professional.course       no  yes   no
# 7  25     services   single          high.school       no  yes   no
# 8  41  blue-collar  married              unknown  unknown   no   no
# 9  25     services   single          high.school       no  yes   no
#
#           7    8    9   ...  11   12  13           14   15      16    17  \
# 0  telephone  may  mon  ...   1  999   0  nonexistent  1.1  93.994 -36.4
# ...

# %%
bankDF.head(10)
# Out:
#    age          job  marital            education  default housing loan  \
# 0   56    housemaid  married             basic.4y       no      no   no
# 1   57     services  married          high.school  unknown      no   no
# 2   37     services  married          high.school       no     yes   no
# 3   40       admin.  married             basic.6y       no      no   no
# 4   56     services  married          high.school       no      no  yes
# 5   45     services  married             basic.9y  unknown      no   no
# 6   59       admin.  married  professional.course       no      no   no
# 7   41  blue-collar  married              unknown  unknown      no   no
# 8   24   technician   single  professional.course       no     yes   no
# 9   25     services   single          high.school       no     yes   no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0  telephone   may         mon  ...         1    999         0  nonexistent
# ...

# %%
bankDF.tail(2)
# Out:
#        0           1        2                    3   4    5   6         7   \
# 41184  44  technician  married  professional.course  no   no  no  cellular
# 41185  74     retired  married  professional.course  no  yes  no  cellular
#
#         8    9   ...  11   12  13           14   15      16    17     18  \
# 41184  nov  fri  ...   1  999   0  nonexistent -1.1  94.767 -50.8  1.028
# 41185  nov  fri  ...   3  999   1      failure -1.1  94.767 -50.8  1.028
#
#            19   20
# 41184  4963.6  yes
# 41185  4963.6   no
#
# [2 rows x 21 columns]

# %%
bankDF = pd.read_csv("All_data_files\\bank-additional-full.csv", sep=';', names=['ct', 'kt', 'rt', 'rt', 'yt'])
bankDF.head()
# Out:
# C:\Users\OMKARA\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2714: DtypeWarning: Columns (0,10,11,12,13,15,16,17,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                                                                                                                                                           ct  \
# age job       marital education   default housing loan contact   month day_of_week duration campaign pdays previous poutcome    emp.var.rate  cons.price.idx
# 56  housemaid married basic.4y    no      no      no   telephone may   mon         261      1        999   0        nonexistent 1.1                   93.994
# 57  services  married high.school unknown no      no   telephone may   mon         149      1        999   0        nonexistent 1.1                   93.994
# ...

# %%
bankDF.columns.dtype
# Out:
# dtype('O')

# %%
type(bankDF['ct'])
# Out:
# pandas.core.series.Series

# %%
bankDF.dtypes
# Out:
# ct      object
# kt      object
# rt      object
# rt.1    object
# yt      object
# dtype: object

# %%
bankDF.dtypes.isnull().sum
# Out:
# <bound method Series.sum of ct      False
# kt      False
# rt      False
# rt.1    False
# yt      False
# dtype: bool>

# %%
bankDF.isnull()
# Out:
#                                                                                                                                                               ct  \
# age job           marital  education           default housing loan contact   month day_of_week duration campaign pdays previous poutcome    emp.var.rate  False
# 56  housemaid     married  basic.4y            no      no      no   telephone may   mon         261      1        999   0        nonexistent 1.1           False
# 57  services      married  high.school         unknown no      no   telephone may   mon         149      1        999   0        nonexistent 1.1           False
# 37  services      married  high.school         no      yes     no   telephone may   mon         226      1        999   0        nonexistent 1.1           False
# 40  admin.        married  basic.6y            no      no      no   telephone may   mon         151      1        999   0        nonexistent 1.1           False
# ...

# %%
bankDF = pd.read_csv("All_data_files\\bank-additional-full.csv", sep=';', nrows=10)
bankDF.head(22)
# Out:
#    age          job  marital            education  default housing loan  \
# 0   56    housemaid  married             basic.4y       no      no   no
# 1   57     services  married          high.school  unknown      no   no
# 2   37     services  married          high.school       no     yes   no
# 3   40       admin.  married             basic.6y       no      no   no
# 4   56     services  married          high.school       no      no  yes
# 5   45     services  married             basic.9y  unknown      no   no
# 6   59       admin.  married  professional.course       no      no   no
# 7   41  blue-collar  married              unknown  unknown      no   no
# 8   24   technician   single  professional.course       no     yes   no
# 9   25     services   single          high.school       no     yes   no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0  telephone   may         mon  ...         1    999         0  nonexistent
# ...

# %%
pd.options.display.max_rows=5

# %%
db = pd.read_csv('All_data_files\\exe1.csv', nrows=2)
db
# Out:
#    a  b    c  d message
# 0  1  2  3.0  4   hello
# 1  5  6  NaN  8   world

# %%
db = pd.read_csv('All_data_files\\exe1.csv')
db
# Out:
#    a   b     c    d message
# 0  1   2   3.0  4.0   hello
# 1  5   6   NaN  8.0   world
# 2  9  10  11.0  NaN     foo

# %% [markdown]
# # @@@@@@@@@@@@@@@@@@@@@@@@@@@@@
# # Remainng Part - 2
# # @@@@@@@@@@@@@@@@@@@@@@@@@@@@@
